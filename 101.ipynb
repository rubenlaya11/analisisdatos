# %%
# Importación de los datos
import pandas as pd
import sqlite3

# %% [markdown]
# ## 1. CARGAR PEDIDOS (CSV)

# %%
# Cargar el fichero pedidos.csv

df_csv = pd.read_csv("pedidos.csv", encoding="utf-16", sep="|", na_values=["NA", "null", "-", "###ERROR###", "-99999.00", "-99999.0"])
df_csv.columns = df_csv.columns.str.strip()

# %% [markdown]
# ## 2. CARGAR CLIENTES (JSON)

# %%
# Cargar el fichero clientes.json
df_json = pd.read_json("clientes.json")

# %% [markdown]
# ## 3. CARGAR PRODUCTOS (SQLite)

# %%
# Cargar el fichero productos.db

with sqlite3.connect("productos.db") as conn:
    df_bd = pd.read_sql_query("SELECT * FROM productos;", conn)

# %% [markdown]
# ## 4. NORMALIZAR TIPOS DE CLAVE

# %%
# Convertimos los valores de las columnas que actuarán de clave a str para evitar conflictos
df_csv.columns = df_csv.columns.str.strip()
df_csv["id_cliente"] = df_csv["id_cliente"].astype(str)
df_csv["id_producto"] = df_csv["id_producto"].astype(str) 
df_csv["Id Pedido"] = df_csv["Id Pedido"].astype(str)

df_json["id_cliente"] = df_json["id_cliente"].astype(str)

df_bd["id_producto"] = df_bd["id_producto"].astype(str)

# %% [markdown]
# ## 5. UNIÓN DE DATASETS

# %%
# Unir los tres datasets en uno solo
df_merged = df_csv.merge(df_json, on='id_cliente', how='left')
df_merged_global = df_merged.merge(df_bd, on='id_producto', how='left')

# %% [markdown]
# ## Apartado 1: Información básica del dataset

# %%
# 1.1 Mostrar las primeras 5 filas del dataset global
print(df_merged_global.head(5))

# 1.2 Mostrar las dimensiones del dataset (filas y columnas)
print(df_merged_global.ndim)

# 1.3 Mostrar los nombres de todas las columnas
print(df_merged_global.columns)

# 1.4 Mostrar información sobre los tipos de datos de las columnas
print(df_merged_global.dtypes)

# 1.5 Mostrar las últimas 3 filas del dataset
print(df_merged_global.tail(3))
# Out:
#   Id Pedido id_cliente id_producto fecha_pedido  cantidad  precio_unitario  \
# 0       1.0     1263.0       531.0   2025-02-28       7.0           356.14
# 1       nan        nan       744.0   2023-11-18       8.0          1569.27
# 2       3.0     3060.0       990.0   2023-10-18      10.0           707.74
# 3       4.0     1216.0       174.0   2024-05-31       3.0          1281.67
# 4       5.0     1558.0       916.0   2024-06-30       9.0          1208.76
#
#       total    metodo_pago estado_pedido        País envío  ... genero edad  \
# 0   2492.98        Tarjeta     Pendiente           Namibia  ...    NaN  NaN
# 1  12554.16  Transferencia     Pendiente  Christmas Island  ...    NaN  NaN
# 2   7077.40         PayPal     Pendiente          Tanzania  ...    NaN  NaN
# 3   3845.01   Criptomoneda     Pendiente          Bulgaria  ...    NaN  NaN
# 4  10878.84         PayPal       Enviado           Romania  ...    NaN  NaN
#
#   nivel_fidelizacion nombre_producto    categoria precio_base  descuento  \
# 0                NaN    Business Pro  Electrónica     1174.25       10.0
# 1                NaN       Serve Max  Electrónica     1144.23       10.0
# 2                NaN     Economy Max         Ropa      633.15          1
# 3                NaN        Only Max  Electrónica      348.97       20.0
# 4                NaN           Own X      Deporte      823.87       10.0
#
#    stock                    proveedor  fecha_alta
# 0  398.0                    Brown PLC  2024-04-02
# 1  443.0              Curry-Daugherty  2025-04-08
# 2  443.0      Rocha, Nixon and Hinton  2023-10-28
# 3  324.0  Ramsey, Anderson and Rivera  2025-03-29
# 4  404.0   Alvarado, Rodriguez and Wu  2023-04-05
#
# [5 rows x 25 columns]
# 2
# Index(['Id Pedido', 'id_cliente', 'id_producto', 'fecha_pedido', 'cantidad',
#        'precio_unitario', 'total', 'metodo_pago', 'estado_pedido',
#        'País envío', 'nombre', 'email', 'telefono', 'direccion',
#        'fecha_registro', 'genero', 'edad', 'nivel_fidelizacion',
#        'nombre_producto', 'categoria', 'precio_base', 'descuento', 'stock',
#        'proveedor', 'fecha_alta'],
#       dtype='object')
# Id Pedido              object
# id_cliente             object
# id_producto            object
# fecha_pedido           object
# cantidad              float64
# precio_unitario       float64
# total                 float64
# metodo_pago            object
# estado_pedido          object
# País envío             object
# nombre                 object
# email                  object
# telefono               object
# direccion              object
# fecha_registro         object
# genero                 object
# edad                  float64
# nivel_fidelizacion     object
# nombre_producto        object
# categoria              object
# precio_base            object
# descuento              object
# stock                  object
# proveedor              object
# fecha_alta             object
# dtype: object
#       Id Pedido id_cliente id_producto fecha_pedido  cantidad  \
# 39997   39998.0     4163.0       196.0   2025-01-26       6.0
# 39998   39999.0     2882.0       521.0   2023-11-04       2.0
# 39999   40000.0     2417.0       284.0           20       6.0
#
#        precio_unitario     total   metodo_pago estado_pedido    País envío  \
# 39997          1855.47  11132.82  Criptomoneda     Cancelado    Martinique
# 39998           939.56   1879.12       Tarjeta      Devuelto       Ukraine
# 39999           594.50   3567.00        PayPal     Pendiente  Saint Martin
#
#        ... genero edad nivel_fidelizacion nombre_producto categoria  \
# 39997  ...    NaN  NaN                NaN       Control X        Li
# 39998  ...    NaN  NaN                NaN     Indeed Lite    Libros
# 39999  ...    NaN  NaN                NaN       Agree Max      None
#
#       precio_base  descuento  stock                    proveedor  fecha_alta
# 39997     1319.93       20.0  455.0  Mitchell, Johnson and Hines  2024-02-12
# 39998      248.75        5.0  413.0               Andrews-Harris  2023-08-26
# 39999     1096.38       10.0  469.0   Goodwin, Smith and Hawkins  2023-05-26
#
# [3 rows x 25 columns]

# %% [markdown]
# ## Apartado 2: Tipos de datos y valores nulos

# %%
# 2.1 Mostrar información detallada del DataFrame (tipos, memoria, nulos)
print(df_merged_global.info())


# 2.2 Contar valores nulos por columna

print(df_merged_global.isnull().sum())

# 2.3 Mostrar solo las columnas que tienen valores nulos
print(df_merged_global[df_merged_global.columns[df_merged_global.isnull().any()]])

# 2.4 Calcular el porcentaje de valores nulos por columna
porcentaje_nulos = (df_merged_global.isnull().mean()*100)
print(porcentaje_nulos)

# 2.5 Verificar si hay filas completamente vacías
print(df_merged_global[df_merged_global.isnull().all(axis=1)])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id Pedido           40000 non-null  object
#  1   id_cliente          40000 non-null  object
#  2   id_producto         40000 non-null  object
#  3   fecha_pedido        38728 non-null  object
#  4   cantidad            38700 non-null  float64
#  5   precio_unitario     38637 non-null  float64
#  6   total               38689 non-null  float64
#  7   metodo_pago         38710 non-null  object
#  8   estado_pedido       38692 non-null  object
#  9   País envío          38670 non-null  object
#  10  nombre              0 non-null      object
#  11  email               0 non-null      object
#  12  telefono            0 non-null      object
#  13  direccion           0 non-null      object
#  14  fecha_registro      0 non-null      object
#  15  genero              0 non-null      object
#  16  edad                0 non-null      float64
#  17  nivel_fidelizacion  0 non-null      object
#  18  nombre_producto     36043 non-null  object
#  19  categoria           35996 non-null  object
#  20  precio_base         36024 non-null  object
#  21  descuento           36221 non-null  object
#  22  stock               35946 non-null  object
#  23  proveedor           35979 non-null  object
#  24  fecha_alta          35959 non-null  object
# dtypes: float64(4), object(21)
# memory usage: 7.6+ MB
# None
# Id Pedido                 0
# id_cliente                0
# id_producto               0
# fecha_pedido           1272
# cantidad               1300
# precio_unitario        1363
# total                  1311
# metodo_pago            1290
# estado_pedido          1308
# País envío             1330
# nombre                40000
# email                 40000
# telefono              40000
# direccion             40000
# fecha_registro        40000
# genero                40000
# edad                  40000
# nivel_fidelizacion    40000
# nombre_producto        3957
# categoria              4004
# precio_base            3976
# descuento              3779
# stock                  4054
# proveedor              4021
# fecha_alta             4041
# dtype: int64
#       fecha_pedido  cantidad  precio_unitario     total    metodo_pago  \
# 0       2025-02-28       7.0           356.14   2492.98        Tarjeta
# 1       2023-11-18       8.0          1569.27  12554.16  Transferencia
# 2       2023-10-18      10.0           707.74   7077.40         PayPal
# 3       2024-05-31       3.0          1281.67   3845.01   Criptomoneda
# 4       2024-06-30       9.0          1208.76  10878.84         PayPal
# ...            ...       ...              ...       ...            ...
# 39995   2025-07-15       3.0           543.26   1629.78         PayPal
# 39996   2025-03-07       4.0           134.56    538.24        Tarjeta
# 39997   2025-01-26       6.0          1855.47  11132.82   Criptomoneda
# 39998   2023-11-04       2.0           939.56   1879.12        Tarjeta
# 39999           20       6.0           594.50   3567.00         PayPal
#
#       estado_pedido        País envío nombre email telefono  ... genero edad  \
# 0         Pendiente           Namibia    NaN   NaN      NaN  ...    NaN  NaN
# 1         Pendiente  Christmas Island    NaN   NaN      NaN  ...    NaN  NaN
# 2         Pendiente          Tanzania    NaN   NaN      NaN  ...    NaN  NaN
# 3         Pendiente          Bulgaria    NaN   NaN      NaN  ...    NaN  NaN
# 4           Enviado           Romania    NaN   NaN      NaN  ...    NaN  NaN
# ...             ...               ...    ...   ...      ...  ...    ...  ...
# 39995      Devuelto             Samoa    NaN   NaN      NaN  ...    NaN  NaN
# 39996       Enviado               NaN    NaN   NaN      NaN  ...    NaN  NaN
# 39997     Cancelado        Martinique    NaN   NaN      NaN  ...    NaN  NaN
# 39998      Devuelto           Ukraine    NaN   NaN      NaN  ...    NaN  NaN
# 39999     Pendiente      Saint Martin    NaN   NaN      NaN  ...    NaN  NaN
#
#       nivel_fidelizacion  nombre_producto    categoria precio_base descuento  \
# 0                    NaN     Business Pro  Electrónica     1174.25      10.0
# 1                    NaN        Serve Max  Electrónica     1144.23      10.0
# 2                    NaN      Economy Max         Ropa      633.15         1
# 3                    NaN         Only Max  Electrónica      348.97      20.0
# 4                    NaN            Own X      Deporte      823.87      10.0
# ...                  ...              ...          ...         ...       ...
# 39995                NaN       Beyond Pro      Deporte      539.26       5.0
# 39996                NaN   Generation Pro      Deporte     1977.79       5.0
# 39997                NaN        Control X           Li     1319.93      20.0
# 39998                NaN      Indeed Lite       Libros      248.75       5.0
# 39999                NaN        Agree Max         None     1096.38      10.0
#
#        stock                    proveedor  fecha_alta
# 0      398.0                    Brown PLC  2024-04-02
# 1      443.0              Curry-Daugherty  2025-04-08
# 2      443.0      Rocha, Nixon and Hinton  2023-10-28
# 3      324.0  Ramsey, Anderson and Rivera  2025-03-29
# 4      404.0   Alvarado, Rodriguez and Wu  2023-04-05
# ...      ...                          ...         ...
# 39995  344.0                  Diaz-Hinton          20
# 39996  273.0              Hawkins-Salazar  2024-05-24
# 39997  455.0  Mitchell, Johnson and Hines  2024-02-12
# 39998  413.0               Andrews-Harris  2023-08-26
# 39999  469.0   Goodwin, Smith and Hawkins  2023-05-26
#
# [40000 rows x 22 columns]
# Id Pedido               0.0000
# id_cliente              0.0000
# id_producto             0.0000
# fecha_pedido            3.1800
# cantidad                3.2500
# precio_unitario         3.4075
# total                   3.2775
# metodo_pago             3.2250
# estado_pedido           3.2700
# País envío              3.3250
# nombre                100.0000
# email                 100.0000
# telefono              100.0000
# direccion             100.0000
# fecha_registro        100.0000
# genero                100.0000
# edad                  100.0000
# nivel_fidelizacion    100.0000
# nombre_producto         9.8925
# categoria              10.0100
# precio_base             9.9400
# descuento               9.4475
# stock                  10.1350
# proveedor              10.0525
# fecha_alta             10.1025
# dtype: float64
# Empty DataFrame
# Columns: [Id Pedido, id_cliente, id_producto, fecha_pedido, cantidad, precio_unitario, total, metodo_pago, estado_pedido, País envío, nombre, email, telefono, direccion, fecha_registro, genero, edad, nivel_fidelizacion, nombre_producto, categoria, precio_base, descuento, stock, proveedor, fecha_alta]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# ## Apartado 3: Estadísticas descriptivas

# %%
# 3.1 Estadísticas descriptivas de todas las columnas numéricas
print(df_merged_global.describe())

# 3.2 Estadísticas descriptivas de todas las columnas (numéricas y categóricas)
print(df_merged_global.describe(include='all'))

# 3.3 Calcular la media, mediana y moda de la columna 'total'
print(df_merged_global['total'].mean())
print(df_merged_global['total'].median())
print(df_merged_global['total'].mode())

# 3.4 Calcular el rango (máximo - mínimo) de la columna 'cantidad'
print(df_merged_global['cantidad'].max() - df_merged_global['cantidad'].min())

# 3.5 Calcular la desviación estándar y la varianza de la columna 'total'
print(df_merged_global['total'].std(axis=0))
print(df_merged_global['total'].var())

# 3.6 Contar valores únicos en columnas categóricas

print(df_merged_global.select_dtypes(include='object').nunique())
# Out:
#            cantidad  precio_unitario         total  edad
# count  38700.000000     38637.000000  38689.000000   0.0
# mean       5.493359       981.587831   5411.297785   NaN
# std        2.871951       587.671591   4623.478111   NaN
# min        1.000000         1.000000      1.000000   NaN
# 25%        3.000000       468.680000   1618.200000   NaN
# 50%        5.000000       979.460000   4047.750000   NaN
# 75%        8.000000      1494.940000   8220.780000   NaN
# max       10.000000      2000.000000  19994.400000   NaN
#        Id Pedido id_cliente id_producto fecha_pedido      cantidad  \
# count      40000      40000       40000        38728  38700.000000
# unique     38053       4998        1001          733           NaN
# top          nan        nan         nan           20           NaN
# freq        1320       1341        1320          666           NaN
# mean         NaN        NaN         NaN          NaN      5.493359
# std          NaN        NaN         NaN          NaN      2.871951
# min          NaN        NaN         NaN          NaN      1.000000
# 25%          NaN        NaN         NaN          NaN      3.000000
# 50%          NaN        NaN         NaN          NaN      5.000000
# 75%          NaN        NaN         NaN          NaN      8.000000
# max          NaN        NaN         NaN          NaN     10.000000
#
#         precio_unitario         total metodo_pago estado_pedido País envío  \
# count      38637.000000  38689.000000       38710         38692      38670
# unique              NaN           NaN           9             9        353
# top                 NaN           NaN     Tarjeta     Pendiente      Congo
# freq                NaN           NaN        9594          9609        318
# mean         981.587831   5411.297785         NaN           NaN        NaN
# std          587.671591   4623.478111         NaN           NaN        NaN
# min            1.000000      1.000000         NaN           NaN        NaN
# 25%          468.680000   1618.200000         NaN           NaN        NaN
# 50%          979.460000   4047.750000         NaN           NaN        NaN
# 75%         1494.940000   8220.780000         NaN           NaN        NaN
# max         2000.000000  19994.400000         NaN           NaN        NaN
#
#         ... genero edad nivel_fidelizacion nombre_producto categoria  \
# count   ...      0  0.0                  0           36043     35996
# unique  ...      0  NaN                  0             823        13
# top     ...    NaN  NaN                NaN     ###ERROR###    Libros
# freq    ...    NaN  NaN                NaN             481      6118
# mean    ...    NaN  NaN                NaN             NaN       NaN
# std     ...    NaN  NaN                NaN             NaN       NaN
# min     ...    NaN  NaN                NaN             NaN       NaN
# 25%     ...    NaN  NaN                NaN             NaN       NaN
# 50%     ...    NaN  NaN                NaN             NaN       NaN
# 75%     ...    NaN  NaN                NaN             NaN       NaN
# max     ...    NaN  NaN                NaN             NaN       NaN
#
#        precio_base  descuento   stock    proveedor fecha_alta
# count        36024      36221   35946        35979      35959
# unique         908         11     421          898        614
# top         -99999        0.0  -99999  ###ERROR###         20
# freq           630       7418     745          607        577
# mean           NaN        NaN     NaN          NaN        NaN
# std            NaN        NaN     NaN          NaN        NaN
# min            NaN        NaN     NaN          NaN        NaN
# 25%            NaN        NaN     NaN          NaN        NaN
# 50%            NaN        NaN     NaN          NaN        NaN
# 75%            NaN        NaN     NaN          NaN        NaN
# max            NaN        NaN     NaN          NaN        NaN
#
# [11 rows x 25 columns]
# 5411.29778464163
# 4047.75
# 0    1.0
# Name: total, dtype: float64
# 9.0
# 4623.4781114165135
# 21376549.846747607
# Id Pedido             38053
# id_cliente             4998
# id_producto            1001
# fecha_pedido            733
# metodo_pago               9
# estado_pedido             9
# País envío              353
# nombre                    0
# email                     0
# telefono                  0
# direccion                 0
# fecha_registro            0
# genero                    0
# nivel_fidelizacion        0
# nombre_producto         823
# categoria                13
# precio_base             908
# descuento                11
# stock                   421
# proveedor               898
# fecha_alta              614
# dtype: int64

# %% [markdown]
# ## Apartado 4: Filtrado simple

# %%
# 4.1 Filtrar pedidos con cantidad mayor a 5 unidades
print(df_merged_global[df_merged_global['cantidad']>5])

# 4.2 Filtrar pedidos con total mayor a 1000 euros
print(df_merged_global[df_merged_global['total']>1000])

# 4.3 Filtrar pedidos con precio unitario menor a 50 euros
print(df_merged_global[df_merged_global['precio_unitario']<50])

# 4.4 Filtrar pedidos con cantidad igual a 1
print(df_merged_global[df_merged_global['cantidad']==1])

# 4.5 Mostrar los primeros 5 pedidos grandes (cantidad > 5)
print(df_merged_global[df_merged_global['cantidad']>5].head(5))

# 4.6 Mostrar los primeros 5 pedidos caros (total > 1000€)
print(df_merged_global[df_merged_global['total']>1000].head(5))
# Out:
#       Id Pedido id_cliente id_producto fecha_pedido  cantidad  \
# 0           1.0     1263.0       531.0   2025-02-28       7.0
# 1           nan        nan       744.0   2023-11-18       8.0
# 2           3.0     3060.0       990.0   2023-10-18      10.0
# 4           5.0     1558.0       916.0   2024-06-30       9.0
# 5           6.0     2354.0       373.0   2023-10-08       8.0
# ...         ...        ...         ...          ...       ...
# 39990   39991.0     4968.0       528.0   2025-02-16      10.0
# 39991   39992.0      727.0       194.0   2024-12-20       8.0
# 39992   39993.0     1306.0       422.0   2024-01-06       6.0
# 39997   39998.0     4163.0       196.0   2025-01-26       6.0
# 39999   40000.0     2417.0       284.0           20       6.0
#
#        precio_unitario     total    metodo_pago estado_pedido  \
# 0               356.14   2492.98        Tarjeta     Pendiente
# 1              1569.27  12554.16  Transferencia     Pendiente
# 2               707.74   7077.40         PayPal     Pendiente
# 4              1208.76  10878.84         PayPal       Enviado
# 5              1383.92  11071.36            NaN     Cancelado
# ...                ...       ...            ...           ...
# 39990          1156.39  11563.90        Tarjeta     Cancelado
# 39991           465.40   3723.20        Tarjeta            De
# 39992          1804.95  10829.70         PayPal     Pendiente
# 39997          1855.47  11132.82   Criptomoneda     Cancelado
# 39999           594.50   3567.00         PayPal     Pendiente
#
#              País envío  ... genero edad nivel_fidelizacion nombre_producto  \
# 0               Namibia  ...    NaN  NaN                NaN    Business Pro
# 1      Christmas Island  ...    NaN  NaN                NaN       Serve Max
# 2              Tanzania  ...    NaN  NaN                NaN     Economy Max
# 4               Romania  ...    NaN  NaN                NaN           Own X
# 5              Mongolia  ...    NaN  NaN                NaN        Film Pro
# ...                 ...  ...    ...  ...                ...             ...
# 39990    Czech Republic  ...    NaN  NaN                NaN     According X
# 39991        Luxembourg  ...    NaN  NaN                NaN    Everyone Max
# 39992           Reunion  ...    NaN  NaN                NaN        Poor Max
# 39997        Martinique  ...    NaN  NaN                NaN       Control X
# 39999      Saint Martin  ...    NaN  NaN                NaN       Agree Max
#
#          categoria precio_base  descuento  stock                    proveedor  \
# 0      Electrónica     1174.25       10.0  398.0                    Brown PLC
# 1      Electrónica     1144.23       10.0  443.0              Curry-Daugherty
# 2             Ropa      633.15          1  443.0      Rocha, Nixon and Hinton
# 4          Deporte      823.87       10.0  404.0   Alvarado, Rodriguez and Wu
# 5      Electrónica      908.55        0.0  292.0                   Wright LLC
# ...            ...         ...        ...    ...                          ...
# 39990        Hogar     1982.89        0.0  236.0    Compton, Galvan and Grant
# 39991     Juguetes      386.58       10.0   98.0                  ###ERROR###
# 39992       Libros     1728.38       15.0  493.0                Johnson Group
# 39997           Li     1319.93       20.0  455.0  Mitchell, Johnson and Hines
# 39999         None     1096.38       10.0  469.0   Goodwin, Smith and Hawkins
#
#        fecha_alta
# 0      2024-04-02
# 1      2025-04-08
# 2      2023-10-28
# 4      2023-04-05
# 5      2023-08-14
# ...           ...
# 39990  2024-12-03
# 39991  2024-03-12
# 39992  2024-03-25
# 39997  2024-02-12
# 39999  2023-05-26
#
# [19270 rows x 25 columns]
#       Id Pedido id_cliente id_producto fecha_pedido  cantidad  \
# 0           1.0     1263.0       531.0   2025-02-28       7.0
# 1           nan        nan       744.0   2023-11-18       8.0
# 2           3.0     3060.0       990.0   2023-10-18      10.0
# 3           4.0     1216.0       174.0   2024-05-31       3.0
# 4           5.0     1558.0       916.0   2024-06-30       9.0
# ...         ...        ...         ...          ...       ...
# 39994   39995.0     4890.0       247.0   2024-05-22       1.0
# 39995   39996.0     4739.0       503.0   2025-07-15       3.0
# 39997   39998.0     4163.0       196.0   2025-01-26       6.0
# 39998   39999.0     2882.0       521.0   2023-11-04       2.0
# 39999   40000.0     2417.0       284.0           20       6.0
#
#        precio_unitario     total    metodo_pago estado_pedido  \
# 0               356.14   2492.98        Tarjeta     Pendiente
# 1              1569.27  12554.16  Transferencia     Pendiente
# 2               707.74   7077.40         PayPal     Pendiente
# 3              1281.67   3845.01   Criptomoneda     Pendiente
# 4              1208.76  10878.84         PayPal       Enviado
# ...                ...       ...            ...           ...
# 39994          1689.39   1689.39        Tarjeta            Pe
# 39995           543.26   1629.78         PayPal      Devuelto
# 39997          1855.47  11132.82   Criptomoneda     Cancelado
# 39998           939.56   1879.12        Tarjeta      Devuelto
# 39999           594.50   3567.00         PayPal     Pendiente
#
#              País envío  ... genero edad nivel_fidelizacion nombre_producto  \
# 0               Namibia  ...    NaN  NaN                NaN    Business Pro
# 1      Christmas Island  ...    NaN  NaN                NaN       Serve Max
# 2              Tanzania  ...    NaN  NaN                NaN     Economy Max
# 3              Bulgaria  ...    NaN  NaN                NaN        Only Max
# 4               Romania  ...    NaN  NaN                NaN           Own X
# ...                 ...  ...    ...  ...                ...             ...
# 39994             Yemen  ...    NaN  NaN                NaN            None
# 39995             Samoa  ...    NaN  NaN                NaN      Beyond Pro
# 39997        Martinique  ...    NaN  NaN                NaN       Control X
# 39998           Ukraine  ...    NaN  NaN                NaN     Indeed Lite
# 39999      Saint Martin  ...    NaN  NaN                NaN       Agree Max
#
#          categoria precio_base  descuento  stock                    proveedor  \
# 0      Electrónica     1174.25       10.0  398.0                    Brown PLC
# 1      Electrónica     1144.23       10.0  443.0              Curry-Daugherty
# 2             Ropa      633.15          1  443.0      Rocha, Nixon and Hinton
# 3      Electrónica      348.97       20.0  324.0  Ramsey, Anderson and Rivera
# 4          Deporte      823.87       10.0  404.0   Alvarado, Rodriguez and Wu
# ...            ...         ...        ...    ...                          ...
# 39994     Juguetes      252.65       15.0  283.0                  Wheeler LLC
# 39995      Deporte      539.26        5.0  344.0                  Diaz-Hinton
# 39997           Li     1319.93       20.0  455.0  Mitchell, Johnson and Hines
# 39998       Libros      248.75        5.0  413.0               Andrews-Harris
# 39999         None     1096.38       10.0  469.0   Goodwin, Smith and Hawkins
#
#        fecha_alta
# 0      2024-04-02
# 1      2025-04-08
# 2      2023-10-28
# 3      2025-03-29
# 4      2023-04-05
# ...           ...
# 39994  2022-12-24
# 39995          20
# 39997  2024-02-12
# 39998  2023-08-26
# 39999  2023-05-26
#
# [32451 rows x 25 columns]
#       Id Pedido id_cliente id_producto fecha_pedido  cantidad  \
# 15         16.0     1323.0       942.0   2023-11-24       9.0
# 22         23.0     4602.0       332.0   2024-11-27       3.0
# 46         47.0       57.0       729.0   2025-05-10       1.0
# 70         71.0     1030.0        39.0   2025-09-15       4.0
# 82         83.0     3331.0       213.0   2025-06-24       2.0
# ...         ...        ...         ...          ...       ...
# 39812   39813.0     3765.0        15.0   2025-01-15       8.0
# 39843   39844.0      117.0       933.0   2025-09-20      10.0
# 39875   39876.0     2215.0       904.0   2025-03-15       5.0
# 39916   39917.0     2825.0        28.0   2024-09-08       8.0
# 39934   39935.0        nan       472.0   2024-03-05       1.0
#
#        precio_unitario     total    metodo_pago estado_pedido  \
# 15               38.69    348.21        Tarjeta     Cancelado
# 22               32.04     96.12        Tarjeta     Pendiente
# 46                7.38      7.38   Criptomoneda      Devuelto
# 70               25.27    101.08  Transferencia     Cancelado
# 82                4.00     84.68         PayPal      Devuelto
# ...                ...       ...            ...           ...
# 39812             1.00  15964.40   Criptomoneda       Enviado
# 39843            32.86    328.60        Tarjeta       Enviado
# 39875            34.52    172.60         PayPal       Enviado
# 39916             1.00  10194.40             Cr     Pendiente
# 39934             1.00      1.00         PayPal       Enviado
#
#                              País envío  ... genero edad nivel_fidelizacion  \
# 15                                Qatar  ...    NaN  NaN                NaN
# 22                               Monaco  ...    NaN  NaN                NaN
# 46                               Brazil  ...    NaN  NaN                NaN
# 70                          Isle of Man  ...    NaN  NaN                NaN
# 82                             Cambodia  ...    NaN  NaN                NaN
# ...                                 ...  ...    ...  ...                ...
# 39812                        Tajikistan  ...    NaN  NaN                NaN
# 39843                             Samoa  ...    NaN  NaN                NaN
# 39875                             Congo  ...    NaN  NaN                NaN
# 39916                            Norway  ...    NaN  NaN                NaN
# 39934  Lao People's Democratic Republic  ...    NaN  NaN                NaN
#
#       nombre_producto    categoria precio_base  descuento   stock  \
# 15                NaN          NaN         NaN        NaN     NaN
# 22           Some Max  Electrónica      1739.0        5.0   488.0
# 46        Knowledge X         Ropa     1726.16        0.0  -99999
# 70         Avoid Lite       Libros      392.78        5.0   494.0
# 82         Major Lite     Juguetes     1440.55       10.0   220.0
# ...               ...          ...         ...        ...     ...
# 39812        High Pro        Hogar     1178.34       10.0   357.0
# 39843       Herself X      Deporte     1423.38       20.0    65.0
# 39875        Book Pro  Electrónica      252.61        5.0   369.0
# 39916            It X      Deporte      873.04        5.0   249.0
# 39934        Skin Pro         Ropa     1080.31        0.0   173.0
#
#                         proveedor  fecha_alta
# 15                            NaN         NaN
# 22                           None  2024-06-17
# 46               Spencer and Sons  2023-02-08
# 70                    Drake Group  2024-06-19
# 82              Gonzalez and Sons  2023-01-22
# ...                           ...         ...
# 39812  Cook, Johnson and Williams  2023-02-10
# 39843          Mercado-Stephenson  2025-02-11
# 39875     Cox, Garcia and Douglas  2024-02-28
# 39916      Briggs, Key and Forbes  2022-11-17
# 39934               Allen-Aguilar          20
#
# [1510 rows x 25 columns]
#       Id Pedido id_cliente id_producto fecha_pedido  cantidad  \
# 10         11.0      317.0       102.0   2024-06-17       1.0
# 31         32.0      494.0       489.0   2025-08-04       1.0
# 42         43.0     2530.0       193.0   2024-01-18       1.0
# 44         45.0     2884.0       863.0   2023-12-16       1.0
# 46         47.0       57.0       729.0   2025-05-10       1.0
# ...         ...        ...         ...          ...       ...
# 39974   39975.0     2321.0       640.0   2024-08-17       1.0
# 39978   39979.0      615.0       205.0   2024-03-26       1.0
# 39982   39983.0     4479.0       912.0   2024-04-07       1.0
# 39986   39987.0     2401.0       793.0   2023-11-20       1.0
# 39994   39995.0     4890.0       247.0   2024-05-22       1.0
#
#        precio_unitario    total    metodo_pago estado_pedido  \
# 10              985.33   985.33         PayPal      Devuelto
# 31             1623.35  1623.35        Tarjeta     Cancelado
# 42             1907.86  1907.86  Transferencia     Pendiente
# 44             1550.32  1550.32   Criptomoneda      Devuelto
# 46                7.38     7.38   Criptomoneda      Devuelto
# ...                ...      ...            ...           ...
# 39974           273.64   273.64   Criptomoneda     Cancelado
# 39978          1450.47      NaN        Tarjeta       Enviado
# 39982          1635.03  1635.03         PayPal     Pendiente
# 39986           949.18   949.18   Criptomoneda       Enviado
# 39994          1689.39  1689.39        Tarjeta            Pe
#
#                        País envío  ... genero edad nivel_fidelizacion  \
# 10                Kyrgyz Republic  ...    NaN  NaN                NaN
# 31                            NaN  ...    NaN  NaN                NaN
# 42                         Monaco  ...    NaN  NaN                NaN
# 44                           Guam  ...    NaN  NaN                NaN
# 46                         Brazil  ...    NaN  NaN                NaN
# ...                           ...  ...    ...  ...                ...
# 39974  Slovakia (Slovak Republic)  ...    NaN  NaN                NaN
# 39978                        Cuba  ...    NaN  NaN                NaN
# 39982                       Palau  ...    NaN  NaN                NaN
# 39986                      Rwanda  ...    NaN  NaN                NaN
# 39994                       Yemen  ...    NaN  NaN                NaN
#
#       nombre_producto    categoria precio_base  descuento   stock  \
# 10            Own Max      Deporte     1740.23       20.0   355.0
# 31     Technology Pro  Electrónica     1200.43        0.0   338.0
# 42           Unit Max        Hogar     1854.01       10.0   464.0
# 44           Sit Lite         Ropa      1428.2       10.0   463.0
# 46        Knowledge X         Ropa     1726.16        0.0  -99999
# ...               ...          ...         ...        ...     ...
# 39974     Including X       Libros     1747.53       10.0     7.0
# 39978        Blue Max        Hogar     1855.97       15.0   478.0
# 39982        Need Pro  Electrónica      -99999       20.0   154.0
# 39986            None      Deporte      855.27       20.0    11.0
# 39994            None     Juguetes      252.65       15.0   283.0
#
#                         proveedor  fecha_alta
# 10          Cruz, Stout and Smith  2022-12-06
# 31       Terry, Larson and Nelson  2023-01-19
# 42     Thompson, Reed and Elliott  2024-09-02
# 44                      Smith Ltd  2024-04-17
# 46               Spencer and Sons  2023-02-08
# ...                           ...         ...
# 39974                Oconnell Ltd  2023-10-17
# 39978    Moran, Collins and Davis  2025-01-29
# 39982                Cowan-Martin  2024-04-15
# 39986               Fleming-Smith  2025-01-19
# 39994                 Wheeler LLC  2022-12-24
#
# [3895 rows x 25 columns]
#   Id Pedido id_cliente id_producto fecha_pedido  cantidad  precio_unitario  \
# 0       1.0     1263.0       531.0   2025-02-28       7.0           356.14
# 1       nan        nan       744.0   2023-11-18       8.0          1569.27
# 2       3.0     3060.0       990.0   2023-10-18      10.0           707.74
# 4       5.0     1558.0       916.0   2024-06-30       9.0          1208.76
# 5       6.0     2354.0       373.0   2023-10-08       8.0          1383.92
#
#       total    metodo_pago estado_pedido        País envío  ... genero edad  \
# 0   2492.98        Tarjeta     Pendiente           Namibia  ...    NaN  NaN
# 1  12554.16  Transferencia     Pendiente  Christmas Island  ...    NaN  NaN
# 2   7077.40         PayPal     Pendiente          Tanzania  ...    NaN  NaN
# 4  10878.84         PayPal       Enviado           Romania  ...    NaN  NaN
# 5  11071.36            NaN     Cancelado          Mongolia  ...    NaN  NaN
#
#   nivel_fidelizacion nombre_producto    categoria precio_base  descuento  \
# 0                NaN    Business Pro  Electrónica     1174.25       10.0
# 1                NaN       Serve Max  Electrónica     1144.23       10.0
# 2                NaN     Economy Max         Ropa      633.15          1
# 4                NaN           Own X      Deporte      823.87       10.0
# 5                NaN        Film Pro  Electrónica      908.55        0.0
#
#    stock                   proveedor  fecha_alta
# 0  398.0                   Brown PLC  2024-04-02
# 1  443.0             Curry-Daugherty  2025-04-08
# 2  443.0     Rocha, Nixon and Hinton  2023-10-28
# 4  404.0  Alvarado, Rodriguez and Wu  2023-04-05
# 5  292.0                  Wright LLC  2023-08-14
#
# [5 rows x 25 columns]
#   Id Pedido id_cliente id_producto fecha_pedido  cantidad  precio_unitario  \
# 0       1.0     1263.0       531.0   2025-02-28       7.0           356.14
# 1       nan        nan       744.0   2023-11-18       8.0          1569.27
# 2       3.0     3060.0       990.0   2023-10-18      10.0           707.74
# 3       4.0     1216.0       174.0   2024-05-31       3.0          1281.67
# 4       5.0     1558.0       916.0   2024-06-30       9.0          1208.76
#
#       total    metodo_pago estado_pedido        País envío  ... genero edad  \
# 0   2492.98        Tarjeta     Pendiente           Namibia  ...    NaN  NaN
# 1  12554.16  Transferencia     Pendiente  Christmas Island  ...    NaN  NaN
# 2   7077.40         PayPal     Pendiente          Tanzania  ...    NaN  NaN
# 3   3845.01   Criptomoneda     Pendiente          Bulgaria  ...    NaN  NaN
# 4  10878.84         PayPal       Enviado           Romania  ...    NaN  NaN
#
#   nivel_fidelizacion nombre_producto    categoria precio_base  descuento  \
# 0                NaN    Business Pro  Electrónica     1174.25       10.0
# 1                NaN       Serve Max  Electrónica     1144.23       10.0
# 2                NaN     Economy Max         Ropa      633.15          1
# 3                NaN        Only Max  Electrónica      348.97       20.0
# 4                NaN           Own X      Deporte      823.87       10.0
#
#    stock                    proveedor  fecha_alta
# 0  398.0                    Brown PLC  2024-04-02
# 1  443.0              Curry-Daugherty  2025-04-08
# 2  443.0      Rocha, Nixon and Hinton  2023-10-28
# 3  324.0  Ramsey, Anderson and Rivera  2025-03-29
# 4  404.0   Alvarado, Rodriguez and Wu  2023-04-05
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Apartado 5: Filtrado con múltiples condiciones

# %%
# 5.1 Filtrar pedidos enviados con cantidad mayor a 3
df_merged_global[(df_merged_global['cantidad']>3) & (df_merged_global['estado_pedido']=='Enviado')]

# 5.2 Filtrar pedidos de tarjeta o PayPal con total mayor a 500 euros
df_merged_global[(df_merged_global['metodo_pago']=='Tarjeta') | (df_merged_global['metodo_pago']=='PayPal')]


# 5.3 Filtrar pedidos pendientes o cancelados con cantidad menor a 2
df_merged_global[(df_merged_global['estado_pedido']=='Cancelado') | (df_merged_global['cantidad']<2)]
# 5.4 Filtrar pedidos enviados o devueltos con precio unitario mayor a 100
df_merged_global[(df_merged_global['estado_pedido'].isin(['Devuelto','Cancelado'])) | (df_merged_global['precio_unitario']>100)]

# 5.5 Mostrar los primeros 5 pedidos enviados grandes
print(df_merged_global[(df_merged_global['cantidad']>5) & (df_merged_global['estado_pedido']=='Enviado')].head(5))


# 5.6 Mostrar los primeros 5 pedidos premium
print(df_merged_global[df_merged_global['nivel_fidelizacion']=='Oro'].head(5))
# Out:
#    Id Pedido id_cliente id_producto fecha_pedido  cantidad  precio_unitario  \
# 4        5.0     1558.0       916.0   2024-06-30       9.0          1208.76
# 20      21.0     2225.0       407.0   2024-04-29       8.0           555.18
# 21      22.0     3978.0       686.0          NaN       6.0           462.08
# 24      25.0     1878.0       585.0   2025-07-18       8.0          1315.42
# 26      27.0     2609.0       258.0   2024-10-07      10.0           150.08
#
#        total    metodo_pago estado_pedido  \
# 4   10878.84         PayPal       Enviado
# 20   4441.44         PayPal       Enviado
# 21   2772.48  Transferencia       Enviado
# 24  10523.36   Criptomoneda       Enviado
# 26   1500.80         PayPal       Enviado
#
#                                       País envío  ... genero edad  \
# 4                                        Romania  ...    NaN  NaN
# 20                                       Bahamas  ...    NaN  NaN
# 21                                    Uzbekistan  ...    NaN  NaN
# 24                                      Suriname  ...    NaN  NaN
# 26  Antarctica (the territory South of 60 deg S)  ...    NaN  NaN
#
#    nivel_fidelizacion nombre_producto    categoria precio_base  descuento  \
# 4                 NaN           Own X      Deporte      823.87       10.0
# 20                NaN         Top Max     Juguetes      372.79       20.0
# 21                NaN  Scientist Lite         Ropa      792.09        0.0
# 24                NaN      Group Lite  Electrónica     1568.28       15.0
# 26                NaN          Keep X       Libros     1886.85     -99999
#
#     stock                   proveedor  fecha_alta
# 4   404.0  Alvarado, Rodriguez and Wu  2023-04-05
# 20   61.0                Kent-Frazier  2023-11-08
# 21  166.0                Martin Group  2024-11-28
# 24  293.0       Lopez, Hunt and Mason  2024-11-05
# 26  402.0                   Roman LLC  2023-07-27
#
# [5 rows x 25 columns]
# Empty DataFrame
# Columns: [Id Pedido, id_cliente, id_producto, fecha_pedido, cantidad, precio_unitario, total, metodo_pago, estado_pedido, País envío, nombre, email, telefono, direccion, fecha_registro, genero, edad, nivel_fidelizacion, nombre_producto, categoria, precio_base, descuento, stock, proveedor, fecha_alta]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# ## Apartado 6: Filtrado temporal

# %%
# 6.1 Convertir la columna fecha_pedido a tipo datetime
df_merged_global['fecha_pedido'] = pd.to_datetime(df_merged_global['fecha_pedido'], dayfirst=False, errors='coerce')

# 6.2 Filtrar pedidos del año 2024
print(df_merged_global[df_merged_global['fecha_pedido'].dt.year == 2024])

# 6.3 Filtrar pedidos del mes de enero de 2024
print(df_merged_global[df_merged_global['fecha_pedido'].dt.month == 1])


# 6.4 Filtrar pedidos del primer trimestre de 2024
print(df_merged_global[(df_merged_global['fecha_pedido']>='2024-01-01') & (df_merged_global['fecha_pedido']<='2024-03-01')])

# 6.5 Filtrar pedidos de los lunes (día de la semana = 0)
print(df_merged_global[df_merged_global['fecha_pedido'].dt.day_of_week == 0])

# 6.6 Mostrar los primeros 5 pedidos de 2024
print(df_merged_global[(df_merged_global['fecha_pedido']>='2024-01-01') & (df_merged_global['fecha_pedido']<='2024-12-31')].head(5))
# Out:
#       Id Pedido id_cliente id_producto fecha_pedido  cantidad  \
# 3           4.0     1216.0       174.0   2024-05-31       3.0
# 4           5.0     1558.0       916.0   2024-06-30       9.0
# 7           8.0      285.0       481.0   2024-12-17       7.0
# 8           9.0      374.0       524.0   2024-09-25       3.0
# 10         11.0      317.0       102.0   2024-06-17       1.0
# ...         ...        ...         ...          ...       ...
# 39987   39988.0     2863.0         nan   2024-04-25       4.0
# 39991   39992.0      727.0       194.0   2024-12-20       8.0
# 39992   39993.0     1306.0       422.0   2024-01-06       6.0
# 39993   39994.0     1626.0       895.0   2024-08-26       4.0
# 39994   39995.0     4890.0       247.0   2024-05-22       1.0
#
#        precio_unitario     total    metodo_pago estado_pedido  \
# 3              1281.67   3845.01   Criptomoneda     Pendiente
# 4              1208.76  10878.84         PayPal       Enviado
# 7               187.82   1314.74        Tarjeta      Devuelto
# 8               781.23   2343.69   Criptomoneda       Enviado
# 10              985.33    985.33         PayPal      Devuelto
# ...                ...       ...            ...           ...
# 39987           455.89   1823.56         PayPal     Cancelado
# 39991           465.40   3723.20        Tarjeta            De
# 39992          1804.95  10829.70         PayPal     Pendiente
# 39993          1790.68   7162.72  Transferencia     Cancelado
# 39994          1689.39   1689.39        Tarjeta            Pe
#
#                                          País envío  ... genero edad  \
# 3                                          Bulgaria  ...    NaN  NaN
# 4                                           Romania  ...    NaN  NaN
# 7      Antarctica (the territory South of 60 deg S)  ...    NaN  NaN
# 8                                           Mayotte  ...    NaN  NaN
# 10                                  Kyrgyz Republic  ...    NaN  NaN
# ...                                             ...  ...    ...  ...
# 39987                                Western Sahara  ...    NaN  NaN
# 39991                                    Luxembourg  ...    NaN  NaN
# 39992                                       Reunion  ...    NaN  NaN
# 39993                                    Guadeloupe  ...    NaN  NaN
# 39994                                         Yemen  ...    NaN  NaN
#
#       nivel_fidelizacion nombre_producto    categoria precio_base  descuento  \
# 3                    NaN        Only Max  Electrónica      348.97       20.0
# 4                    NaN           Own X      Deporte      823.87       10.0
# 7                    NaN         Let Pro       Libros      384.89        0.0
# 8                    NaN     Article Pro     Juguetes      1951.3        5.0
# 10                   NaN         Own Max      Deporte     1740.23       20.0
# ...                  ...             ...          ...         ...        ...
# 39987                NaN             NaN          NaN         NaN        NaN
# 39991                NaN    Everyone Max     Juguetes      386.58       10.0
# 39992                NaN        Poor Max       Libros     1728.38       15.0
# 39993                NaN      Customer X      Deporte     1667.49        5.0
# 39994                NaN            None     Juguetes      252.65       15.0
#
#        stock                    proveedor  fecha_alta
# 3      324.0  Ramsey, Anderson and Rivera  2025-03-29
# 4      404.0   Alvarado, Rodriguez and Wu  2023-04-05
# 7      224.0     Jimenez, Knight and King  2023-08-01
# 8      303.0   Barrett, Spears and Larson  2022-12-17
# 10     355.0        Cruz, Stout and Smith  2022-12-06
# ...      ...                          ...         ...
# 39987    NaN                          NaN         NaN
# 39991   98.0                  ###ERROR###  2024-03-12
# 39992  493.0                Johnson Group  2024-03-25
# 39993   49.0                Rivera-Brewer  2025-03-14
# 39994  283.0                  Wheeler LLC  2022-12-24
#
# [19053 rows x 25 columns]
#       Id Pedido id_cliente id_producto fecha_pedido  cantidad  \
# 42         43.0     2530.0       193.0   2024-01-18       1.0
# 49         50.0      730.0       430.0   2025-01-10       4.0
# 52         53.0     2232.0       579.0   2025-01-22       7.0
# 67         68.0     1058.0        63.0   2025-01-14       3.0
# 79          8.0     4441.0       564.0   2024-01-04       6.0
# ...         ...        ...         ...          ...       ...
# 39930   39931.0     1341.0       636.0   2025-01-30       3.0
# 39932   39933.0     3712.0       556.0   2024-01-29       2.0
# 39943       nan     3297.0       394.0   2025-01-31       5.0
# 39992   39993.0     1306.0       422.0   2024-01-06       6.0
# 39997   39998.0     4163.0       196.0   2025-01-26       6.0
#
#        precio_unitario     total    metodo_pago estado_pedido    País envío  \
# 42             1907.86   1907.86  Transferencia     Pendiente        Monaco
# 49              774.39      3.00            NaN      Devuelto     Venezuela
# 52             1234.84   8643.88   Criptomoneda      Devuelto        Israel
# 67              234.71    704.13   Criptomoneda       Enviado  South Africa
# 79              100.88    605.28         PayPal     Cancelado        Taiwan
# ...                ...       ...            ...           ...           ...
# 39930           690.58   2071.74        Tarjeta     Cancelado         Tonga
# 39932           941.63   1883.26   Criptomoneda     Cancelado         Sudan
# 39943           192.89    964.45   Criptomoneda     Cancelado         Macao
# 39992          1804.95  10829.70         PayPal     Pendiente       Reunion
# 39997          1855.47  11132.82   Criptomoneda     Cancelado    Martinique
#
#        ... genero edad nivel_fidelizacion nombre_producto categoria  \
# 42     ...    NaN  NaN                NaN        Unit Max     Hogar
# 49     ...    NaN  NaN                NaN      Affect Max    Libros
# 52     ...    NaN  NaN                NaN      Number Max     Hogar
# 67     ...    NaN  NaN                NaN     Popular Pro    Libros
# 79     ...    NaN  NaN                NaN     ###ERROR###     Hogar
# ...    ...    ...  ...                ...             ...       ...
# 39930  ...    NaN  NaN                NaN        Street X  Juguetes
# 39932  ...    NaN  NaN                NaN         Box Max  Juguetes
# 39943  ...    NaN  NaN                NaN     Instead Pro  Juguetes
# 39992  ...    NaN  NaN                NaN        Poor Max    Libros
# 39997  ...    NaN  NaN                NaN       Control X        Li
#
#       precio_base  descuento  stock                    proveedor  fecha_alta
# 42        1854.01       10.0  464.0   Thompson, Reed and Elliott  2024-09-02
# 49              1       20.0  294.0                   James-Hunt        None
# 52        1341.94       20.0  464.0  Gordon, Young and Rodriguez  2023-11-12
# 67          569.4       20.0  387.0        Walker, Neal and Long  2024-06-06
# 79          575.1        5.0  478.0               Thomas-Salazar  2025-09-18
# ...           ...        ...    ...                          ...         ...
# 39930     1560.87        5.0  440.0                    Rich-Ross  2025-07-20
# 39932      425.66       20.0  425.0              Campbell-Harris  2023-04-23
# 39943        13.0       15.0   21.0                           Wa  2023-05-13
# 39992     1728.38       15.0  493.0                Johnson Group  2024-03-25
# 39997     1319.93       20.0  455.0  Mitchell, Johnson and Hines  2024-02-12
#
# [3256 rows x 25 columns]
#       Id Pedido id_cliente id_producto fecha_pedido  cantidad  \
# 29         30.0     4666.0       956.0   2024-02-07       2.0
# 42         43.0     2530.0       193.0   2024-01-18       1.0
# 74         75.0        nan       886.0   2024-03-01       6.0
# 79          8.0     4441.0       564.0   2024-01-04       6.0
# 95         96.0     3738.0       374.0   2024-01-13       1.0
# ...         ...        ...         ...          ...       ...
# 39932   39933.0     3712.0       556.0   2024-01-29       2.0
# 39938       nan     2485.0       415.0   2024-02-12      10.0
# 39959   39960.0     1985.0        38.0   2024-02-18      10.0
# 39972   39973.0     3524.0        90.0   2024-02-27       3.0
# 39992   39993.0     1306.0       422.0   2024-01-06       6.0
#
#        precio_unitario     total    metodo_pago estado_pedido      País envío  \
# 29             1154.58   2309.16   Criptomoneda     Pendiente         Iceland
# 42             1907.86   1907.86  Transferencia     Pendiente          Monaco
# 74                 NaN   6359.34   Criptomoneda     Pendiente             NaN
# 79              100.88    605.28         PayPal     Cancelado          Taiwan
# 95              877.89    877.89   Criptomoneda     Pendiente           China
# ...                ...       ...            ...           ...             ...
# 39932           941.63   1883.26   Criptomoneda     Cancelado           Sudan
# 39938          1002.71  10027.10  Transferencia     Cancelado              Li
# 39959          1977.83  19778.30         PayPal     Pendiente  Cayman Islands
# 39972          1380.03   4140.09         PayPal      Devuelto          Angola
# 39992          1804.95  10829.70         PayPal     Pendiente         Reunion
#
#        ... genero edad nivel_fidelizacion nombre_producto    categoria  \
# 29     ...    NaN  NaN                NaN       Happy Pro        Hogar
# 42     ...    NaN  NaN                NaN        Unit Max        Hogar
# 74     ...    NaN  NaN                NaN      Reason Pro      Deporte
# 79     ...    NaN  NaN                NaN     ###ERROR###        Hogar
# 95     ...    NaN  NaN                NaN      White Lite  Electrónica
# ...    ...    ...  ...                ...             ...          ...
# 39932  ...    NaN  NaN                NaN         Box Max     Juguetes
# 39938  ...    NaN  NaN                NaN        Doctor X        Hogar
# 39959  ...    NaN  NaN                NaN     Certainly X        Hogar
# 39972  ...    NaN  NaN                NaN        Some Max         Ropa
# 39992  ...    NaN  NaN                NaN        Poor Max       Libros
#
#       precio_base  descuento  stock                   proveedor  fecha_alta
# 29         661.26       None   16.0              Manning-Harris  2022-10-09
# 42        1854.01       10.0  464.0  Thompson, Reed and Elliott  2024-09-02
# 74         668.24        0.0  465.0    Griffin, Allen and Stone  2024-08-25
# 79          575.1        5.0  478.0              Thomas-Salazar  2025-09-18
# 95        1975.39       10.0  332.0             Franklin-Castro  2025-05-19
# ...           ...        ...    ...                         ...         ...
# 39932      425.66       20.0  425.0             Campbell-Harris  2023-04-23
# 39938      380.06        5.0  250.0      Lyons, Peck and Harris  2022-11-14
# 39959     1112.22       20.0  406.0                Greene-Olson  2025-03-24
# 39972     1721.41        5.0   None              Stout and Sons  2024-06-12
# 39992     1728.38       15.0  493.0               Johnson Group  2024-03-25
#
# [3170 rows x 25 columns]
#       Id Pedido id_cliente id_producto fecha_pedido  cantidad  \
# 10         11.0      317.0       102.0   2024-06-17       1.0
# 20         21.0     2225.0       407.0   2024-04-29       8.0
# 25         26.0     2571.0       749.0   2024-03-18       5.0
# 26         27.0     2609.0       258.0   2024-10-07      10.0
# 31         32.0      494.0       489.0   2025-08-04       1.0
# ...         ...        ...         ...          ...       ...
# 39949   39950.0      801.0       867.0   2025-08-04       7.0
# 39965   39966.0     4771.0       190.0   2024-07-01       7.0
# 39975   39976.0     2126.0       637.0   2024-07-22       6.0
# 39986   39987.0     2401.0       793.0   2023-11-20       1.0
# 39993   39994.0     1626.0       895.0   2024-08-26       4.0
#
#        precio_unitario     total    metodo_pago estado_pedido  \
# 10              985.33    985.33         PayPal      Devuelto
# 20              555.18   4441.44         PayPal       Enviado
# 25             1582.55       NaN        Tarjeta     Cancelado
# 26              150.08   1500.80         PayPal       Enviado
# 31             1623.35   1623.35        Tarjeta     Cancelado
# ...                ...       ...            ...           ...
# 39949          1452.92  10170.44  Transferencia       Enviado
# 39965           207.80   1454.60   Criptomoneda     Cancelado
# 39975          1022.71   6136.26        Tarjeta     Pendiente
# 39986           949.18    949.18   Criptomoneda       Enviado
# 39993          1790.68   7162.72  Transferencia     Cancelado
#
#                                          País envío  ... genero edad  \
# 10                                  Kyrgyz Republic  ...    NaN  NaN
# 20                                          Bahamas  ...    NaN  NaN
# 25                                          Somalia  ...    NaN  NaN
# 26     Antarctica (the territory South of 60 deg S)  ...    NaN  NaN
# 31                                              NaN  ...    NaN  NaN
# ...                                             ...  ...    ...  ...
# 39949                    Slovakia (Slovak Republic)  ...    NaN  NaN
# 39965                                      Cambodia  ...    NaN  NaN
# 39975                                       Grenada  ...    NaN  NaN
# 39986                                        Rwanda  ...    NaN  NaN
# 39993                                    Guadeloupe  ...    NaN  NaN
#
#       nivel_fidelizacion nombre_producto    categoria precio_base  descuento  \
# 10                   NaN         Own Max      Deporte     1740.23       20.0
# 20                   NaN         Top Max     Juguetes      372.79       20.0
# 25                   NaN         Store X     Juguetes     1821.77        0.0
# 26                   NaN          Keep X       Libros     1886.85     -99999
# 31                   NaN  Technology Pro  Electrónica     1200.43        0.0
# ...                  ...             ...          ...         ...        ...
# 39949                NaN     Culture Max           Ho     1447.12       10.0
# 39965                NaN            None      Deporte      677.47       15.0
# 39975                NaN       Happy Pro        Hogar     1530.25       15.0
# 39986                NaN            None      Deporte      855.27       20.0
# 39993                NaN      Customer X      Deporte     1667.49        5.0
#
#        stock                   proveedor  fecha_alta
# 10     355.0       Cruz, Stout and Smith  2022-12-06
# 20      61.0                Kent-Frazier  2023-11-08
# 25         1                Whitaker PLC  2024-01-14
# 26     402.0                   Roman LLC  2023-07-27
# 31     338.0    Terry, Larson and Nelson  2023-01-19
# ...      ...                         ...         ...
# 39949   54.0  Carroll, Howard and Obrien  2025-05-20
# 39965  499.0      Walls, Hudson and Yang  2023-05-07
# 39975  276.0   Smith, Gibson and Ramirez  2025-08-13
# 39986   11.0               Fleming-Smith  2025-01-19
# 39993   49.0               Rivera-Brewer  2025-03-14
#
# [5413 rows x 25 columns]
#    Id Pedido id_cliente id_producto fecha_pedido  cantidad  precio_unitario  \
# 3        4.0     1216.0       174.0   2024-05-31       3.0          1281.67
# 4        5.0     1558.0       916.0   2024-06-30       9.0          1208.76
# 7        8.0      285.0       481.0   2024-12-17       7.0           187.82
# 8        9.0      374.0       524.0   2024-09-25       3.0           781.23
# 10      11.0      317.0       102.0   2024-06-17       1.0           985.33
#
#        total   metodo_pago estado_pedido  \
# 3    3845.01  Criptomoneda     Pendiente
# 4   10878.84        PayPal       Enviado
# 7    1314.74       Tarjeta      Devuelto
# 8    2343.69  Criptomoneda       Enviado
# 10    985.33        PayPal      Devuelto
#
#                                       País envío  ... genero edad  \
# 3                                       Bulgaria  ...    NaN  NaN
# 4                                        Romania  ...    NaN  NaN
# 7   Antarctica (the territory South of 60 deg S)  ...    NaN  NaN
# 8                                        Mayotte  ...    NaN  NaN
# 10                               Kyrgyz Republic  ...    NaN  NaN
#
#    nivel_fidelizacion nombre_producto    categoria precio_base  descuento  \
# 3                 NaN        Only Max  Electrónica      348.97       20.0
# 4                 NaN           Own X      Deporte      823.87       10.0
# 7                 NaN         Let Pro       Libros      384.89        0.0
# 8                 NaN     Article Pro     Juguetes      1951.3        5.0
# 10                NaN         Own Max      Deporte     1740.23       20.0
#
#     stock                    proveedor  fecha_alta
# 3   324.0  Ramsey, Anderson and Rivera  2025-03-29
# 4   404.0   Alvarado, Rodriguez and Wu  2023-04-05
# 7   224.0     Jimenez, Knight and King  2023-08-01
# 8   303.0   Barrett, Spears and Larson  2022-12-17
# 10  355.0        Cruz, Stout and Smith  2022-12-06
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Apartado 7: Estado del pedido

# %%
# 7.1 Contar el número de pedidos por cada estado
df_merged_global.groupby('estado_pedido').size()

# 7.2 Calcular el porcentaje de pedidos por estado
print(df_merged_global['estado_pedido'].value_counts(normalize=True)*100)

# 7.3 Calcular el total de ventas por estado
print(df_merged_global.groupby('estado_pedido')['total'].sum())

# 7.4 Calcular el valor promedio de pedidos por estado
print(df_merged_global.groupby('estado_pedido')['total'].mean())

# 7.5 Calcular la cantidad total de productos vendidos por estado
print(df_merged_global.groupby('estado_pedido')['cantidad'].sum())

# 7.6 Mostrar estadísticas completas por estado
print(df_merged_global.groupby('estado_pedido').agg(
    cantidad_pedidos = ('total','count'),
    total_ventas = ('cantidad','sum'),
    media_ventas = ('cantidad', 'mean')
))
# Out:
# estado_pedido
# Pendiente    24.834591
# Cancelado    24.671767
# Devuelto     24.614907
# Enviado      24.113512
# De            0.467797
# Ca            0.441952
# Pe            0.431614
# En            0.405769
# ##            0.018092
# Name: proportion, dtype: float64
# estado_pedido
# ##              22051.05
# Ca             984724.44
# Cancelado    50191215.62
# De             925505.48
# Devuelto     49753601.27
# En             826068.69
# Enviado      48321220.31
# Pe             885745.99
# Pendiente    50732206.15
# Name: total, dtype: float64
# estado_pedido
# ##           3150.150000
# Ca           5896.553533
# Cancelado    5433.713935
# De           5199.468989
# Devuelto     5402.128260
# En           5399.141765
# Enviado      5360.685635
# Pe           5335.819217
# Pendiente    5458.010344
# Name: total, dtype: float64
# estado_pedido
# ##              30.0
# Ca             920.0
# Cancelado    50651.0
# De             904.0
# Devuelto     50897.0
# En             828.0
# Enviado      49582.0
# Pe             836.0
# Pendiente    51191.0
# Name: cantidad, dtype: float64
#                cantidad_pedidos  total_ventas  media_ventas
# estado_pedido
# ##                            7          30.0      4.285714
# Ca                          167         920.0      5.750000
# Cancelado                  9237       50651.0      5.477560
# De                          178         904.0      5.349112
# Devuelto                   9210       50897.0      5.521480
# En                          153         828.0      5.307692
# Enviado                    9014       49582.0      5.488377
# Pe                          166         836.0      5.257862
# Pendiente                  9295       51191.0      5.510334

# %% [markdown]
# ## Apartado 8: Método de pago

# %%
# 8.1 Contar el número de pedidos por método de pago
df_merged_global.groupby('metodo_pago').size()

# 8.2 Calcular el porcentaje de uso de cada método de pago
print(df_merged_global['metodo_pago'].value_counts(normalize=True)*100)


# 8.3 Calcular el valor total de ventas por método de pago
print(df_merged_global.groupby('metodo_pago')['total'].sum())


# 8.4 Calcular el valor promedio de pedidos por método de pago
print(df_merged_global.groupby('metodo_pago')['total'].mean())

# 8.5 Calcular la cantidad promedio de productos por método de pago
print(df_merged_global.groupby('estado_pedido')['cantidad'].mean())

# 8.6 Mostrar estadísticas completas por método de pago (numero de pedidos, total de ventas, promedio de pedidos, cantidad total, promedio de la cantidad)
print(df_merged_global.groupby('metodo_pago').agg(
    num_pedidos = ('total','count'),
    total_ventas = ('total','sum'),
    promedio_pedidos = ('total', 'mean'),
    cantidad_total = ('cantidad', 'sum'),
    promedio_cantidad = ('cantidad','mean')
))
# Out:
# metodo_pago
# Tarjeta          24.784293
# Criptomoneda     24.781710
# Transferencia    24.500129
# PayPal           24.381297
# Cr                0.410747
# Pa                0.387497
# Tr                0.382330
# Ta                0.359080
# ##                0.012917
# Name: proportion, dtype: float64
# metodo_pago
# ##                  27252.42
# Cr                 755778.35
# Criptomoneda     49735344.31
# Pa                 757002.32
# PayPal           50108987.00
# Ta                 800707.50
# Tarjeta          49939798.46
# Tr                 816526.50
# Transferencia    49689229.21
# Name: total, dtype: float64
# metodo_pago
# ##               5450.484000
# Cr               4907.651623
# Criptomoneda     5367.509638
# Pa               5331.002254
# PayPal           5478.188149
# Ta               5931.166667
# Tarjeta          5384.344847
# Tr               5790.968085
# Transferencia    5407.468627
# Name: total, dtype: float64
# estado_pedido
# ##           4.285714
# Ca           5.750000
# Cancelado    5.477560
# De           5.349112
# Devuelto     5.521480
# En           5.307692
# Enviado      5.488377
# Pe           5.257862
# Pendiente    5.510334
# Name: cantidad, dtype: float64
#                num_pedidos  total_ventas  promedio_pedidos  cantidad_total  \
# metodo_pago
# ##                       5      27252.42       5450.484000            27.0
# Cr                     154     755778.35       4907.651623           850.0
# Criptomoneda          9266   49735344.31       5367.509638         51059.0
# Pa                     142     757002.32       5331.002254           790.0
# PayPal                9147   50108987.00       5478.188149         50231.0
# Ta                     135     800707.50       5931.166667           777.0
# Tarjeta               9275   49939798.46       5384.344847         50969.0
# Tr                     141     816526.50       5790.968085           773.0
# Transferencia         9189   49689229.21       5407.468627         50334.0
#
#                promedio_cantidad
# metodo_pago
# ##                      5.400000
# Cr                      5.414013
# Criptomoneda            5.491396
# Pa                      5.448276
# PayPal                  5.493329
# Ta                      5.755556
# Tarjeta                 5.510162
# Tr                      5.443662
# Transferencia           5.491381

# %% [markdown]
# ## Apartado 9: País de envío

# %%
# 9.1 Contar el número total de países únicos
df_merged_global['País envío'].nunique()

# 9.2 Mostrar los top 10 países por número de pedidos
print(df_merged_global.groupby('País envío')['Id Pedido'].count().sort_values(ascending=False).head(10))

# 9.3 Mostrar los top 10 países por valor total de ventas
print(df_merged_global.groupby('País envío')['total'].sum().sort_values(ascending=False).head(10))


# 9.4 Calcular el valor promedio de pedidos por país (top 10)
print(df_merged_global.groupby('País envío')['total'].mean().sort_values(ascending=False).head(10))


# 9.5 Calcular la cantidad total de productos enviados por país (top 10)
print(df_merged_global[df_merged_global['estado_pedido'] == 'Enviado'].groupby('País envío')['cantidad'].sum().sort_values(ascending=False).head(10))


# 9.6 Mostrar estadísticas del país con más pedidos (número de pedidos, total de ventas, promedio de pedido y total de cantidad)
print(df_merged_global.groupby('País envío').agg(
    num_pedidos = ('total','count'),
    total_ventas = ('total','sum'),
    promedio_pedidos = ('total', 'mean'),
    cantidad_total = ('cantidad', 'sum')
))
# Out:
# País envío
# Congo               318
# Korea               310
# Iran                191
# Venezuela           191
# Sierra Leone        184
# Uruguay             183
# Eritrea             182
# Pitcairn Islands    182
# Palau               182
# Cote d'Ivoire       182
# Name: Id Pedido, dtype: int64
# País envío
# Congo                 1600679.97
# Korea                 1482039.93
# Dominican Republic    1028961.00
# Palau                 1017805.42
# Pitcairn Islands       999687.78
# Cote d'Ivoire          998346.05
# Nigeria                983859.44
# Venezuela              973146.71
# Germany                972725.41
# Uruguay                972009.85
# Name: total, dtype: float64
# País envío
# Hu    14561.200000
# Ga    13605.400000
# He    12034.135000
# Cu    11604.790000
# Ph    11538.990000
# Me    11236.290000
# Ro    10888.260000
# Ke    10836.420000
# Bh    10472.353333
# Ur    10292.565000
# Name: total, dtype: float64
# País envío
# Congo                                           375.0
# Korea                                           367.0
# San Marino                                      299.0
# Cameroon                                        297.0
# Pitcairn Islands                                286.0
# Azerbaijan                                      274.0
# Iran                                            271.0
# Micronesia                                      270.0
# Brazil                                          255.0
# Antarctica (the territory South of 60 deg S)    254.0
# Name: cantidad, dtype: float64
#              num_pedidos  total_ventas  promedio_pedidos  cantidad_total
# País envío
# ##                     5       8920.70       1784.140000            27.0
# Af                     5      31446.50       6289.300000            25.0
# Afghanistan          161     859492.32       5338.461615           917.0
# Al                     4      29777.96       7444.490000            23.0
# Albania              135     635774.39       4709.439926           766.0
# ...                  ...           ...               ...             ...
# Yemen                155     822449.59       5306.126387           858.0
# Za                     1       4886.10       4886.100000             0.0
# Zambia               159     951687.77       5985.457673           892.0
# Zi                     4      22906.95       5726.737500            25.0
# Zimbabwe             147     841879.16       5727.069116           870.0
#
# [353 rows x 4 columns]

# %% [markdown]
# ## Apartado 10: Análisis demográfico

# %%
# 10.1 Contar el número total de clientes únicos
print(df_merged_global['id_cliente'].nunique())

# 10.2 Distribución de clientes por género
print(df_merged_global.groupby('genero')['id_cliente'].count())

# 10.3 Porcentaje de distribución por género
print(df_merged_global['genero'].value_counts(normalize=True) * 100)

# 10.4 Distribución de clientes por nivel de fidelización
print(df_merged_global.groupby('nivel_fidelizacion')['id_cliente'].count())

# 10.5 Estadísticas básicas de edad
print(f"Suma: {df_merged_global['edad'].sum()}")
print(f"Media: {df_merged_global['edad'].mean()}")
print(f"Mediana: {df_merged_global['edad'].median()}")
print(f"Desviación estándar: {df_merged_global['edad'].std()}")
print(f"Varianza: {df_merged_global['edad'].var()}")
print(f"Mínimo: {df_merged_global['edad'].min()}")
print(f"Máximo: {df_merged_global['edad'].max()}")

# 10.6 Mostrar estadísticas completas de edad por género (número de clientes, edad promedio, edad mínima, edad máxima y mediana de edad)
print(df_merged_global.groupby('genero').agg(
    num_clientes = ('id_cliente','count'),
    edad_promedio = ('edad','mean'),
    edad_min = ('edad', 'min'),
    edad_max = ('edad', 'max'),
    edad_mediana = ('edad', 'median')
))
# Out:
# 4998
# Series([], Name: id_cliente, dtype: int64)
# Series([], Name: proportion, dtype: float64)
# Series([], Name: id_cliente, dtype: int64)
# Suma: 0.0
# Media: nan
# Mediana: nan
# Desviación estándar: nan
# Varianza: nan
# Mínimo: nan
# Máximo: nan
# Empty DataFrame
# Columns: [num_clientes, edad_promedio, edad_min, edad_max, edad_mediana]
# Index: []
# c:\Users\ruben\AppData\Local\Programs\Python\Python314\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %% [markdown]
# ## Apartado 11: Clientes por país

# %%
# 11.1 Contar el número total de países únicos donde viven los clientes
df_merged_global['País envío'].nunique()


# 11.2 Mostrar los top 15 países con más clientes
top15 = df_merged_global.groupby('País envío')['id_cliente'].count().sort_values(ascending=False).head(15)
print(top15)

# 11.3 Calcular el porcentaje de clientes por país (top 10)
clientes_pais = df_merged_global.groupby('País envío')['id_cliente'].nunique()
clientes_total = df_merged_global['id_cliente'].nunique()
porcentaje = (clientes_pais/clientes_total)*100
print(porcentaje.sort_values(ascending=False).head(10))

# 11.4 Mostrar estadísticas (número de clientes, edad promedio, edad mínima, edad máxima y mediana de edad) de edad por país (top 5 países)
print(df_merged_global.groupby('País envío').agg(
    num_clientes = ('id_cliente','count'),
    edad_promedio = ('edad','mean'),
    edad_min = ('edad', 'min'),
    edad_max = ('edad', 'max'),
    edad_mediana = ('edad', 'median')
).sort_values(by='num_clientes',ascending=False).head(5))

# 11.5 Mostrar distribución de género por país (top 3 países)
top3 = df_merged_global['País envío'].value_counts().head(3).index
df_top3 = df_merged_global[df_merged_global['País envío'].isin(top3)]
df_top3.groupby(['País envío', 'genero']).size()


# 11.6 Mostrar distribución de nivel de fidelización por país (top 3 países)
top3 = df_merged_global['País envío'].value_counts().head(3).index
df_top3 = df_merged_global[df_merged_global['País envío'].isin(top3)]
print(df_top3.groupby(['País envío', 'nivel_fidelizacion']).size())
# Out:
# País envío
# Congo                       318
# Korea                       310
# Iran                        191
# Venezuela                   191
# Sierra Leone                184
# Uruguay                     183
# Eritrea                     182
# Pitcairn Islands            182
# Palau                       182
# Cote d'Ivoire               182
# Saint Barthelemy            181
# United States of America    180
# Dominican Republic          179
# Nigeria                     179
# San Marino                  179
# Name: id_cliente, dtype: int64
# País envío
# Congo               5.922369
# Korea               5.782313
# Iran                3.701481
# Venezuela           3.641457
# Cote d'Ivoire       3.541417
# Pitcairn Islands    3.541417
# Uruguay             3.481393
# Guam                3.481393
# Palau               3.481393
# Saint Barthelemy    3.461385
# Name: id_cliente, dtype: float64
#               num_clientes  edad_promedio  edad_min  edad_max  edad_mediana
# País envío
# Congo                  318            NaN       NaN       NaN           NaN
# Korea                  310            NaN       NaN       NaN           NaN
# Iran                   191            NaN       NaN       NaN           NaN
# Venezuela              191            NaN       NaN       NaN           NaN
# Sierra Leone           184            NaN       NaN       NaN           NaN
# Series([], dtype: int64)

# %% [markdown]
# ## Apartado 12: Clientes por ciudad

# %%
# 12.1 Mostrar las top 20 ciudades con más clientes
df_json['direccion'] = df_json['direccion'].apply(lambda x: x if isinstance(x, dict) else None)# 12.2 Mostrar las ciudades con exactamente 1 cliente
df_json['ciudad'] = df_json['direccion'].apply(
    lambda x: x.get('ciudad') if isinstance(x, dict) else None
)

print(df_json.groupby('ciudad')['id_cliente'].nunique().sort_values(ascending=False).head(20))

# 12.2 Mostrar las ciudades con exactamente 1 cliente
clientes_ciudad = df_json.groupby('ciudad')['id_cliente'].nunique()
clientes_1_ciudad = clientes_ciudad[clientes_ciudad==1]
print(clientes_1_ciudad)

# 12.3 Mostrar las ciudades con más de 10 clientes
clientes_10_ciudad = clientes_ciudad[clientes_ciudad>=10]
print(clientes_10_ciudad)
# Out:
# ciudad
# New Michael        8
# West Jessica       7
# South Michael      6
# Port Matthew       6
# Williamsmouth      6
# Lake John          5
# New Christopher    5
# New Jessica        5
# Port David         5
# East James         5
# Lake Joseph        5
# Lake Michael       5
# South Jennifer     5
# New Danielle       5
# East Nicole        4
# East Matthew       4
# New Emily          4
# North Matthew      4
# South Kimberly     4
# North Beth         4
# Name: id_cliente, dtype: int64
# ciudad
# Aaronborough     1
# Aaronport        1
# Aaronview        1
# Adambury         1
# Adamland         1
#                 ..
# Yvonneborough    1
# Zacharyland      1
# Zacharyside      1
# Zavalaland       1
# Zimmermanview    1
# Name: id_cliente, Length: 3765, dtype: int64
# Series([], Name: id_cliente, dtype: int64)

# %% [markdown]
# ## Apartado 13: Categoría de productos

# %%
# 13.1 Mostrar las categorías cuyo nombre tiene más de 6 caracteres y que tienen entre 50 y 160 productos
categorias = df_merged_global.groupby('categoria')['id_producto'].count()
len_categorias = categorias[(categorias.index.str.len()>6) & (categorias.between(50,160))]
print(len_categorias)

# 13.2 Mostrar las categorías que contienen la letra "o" (mayúscula o minúscula) y tienen menos de 120 productos
categorias_o = categorias[(categorias.index.str.contains('o', case=False)) & (categorias < 120)]
print(categorias_o)
# Out:
# Series([], Name: id_producto, dtype: int64)
# Series([], Name: id_producto, dtype: int64)

# %% [markdown]
# ## Apartado 14: Precios

# %%
# 14.1 Mostrar estadísticas básicas de precios base (precio promedio, precio mínimo, precio máximo y mediana)
df_merged_global['precio_base'] = pd.to_numeric(df_merged_global['precio_base'], errors='coerce')

promedio = df_merged_global['precio_base'].mean()
min = df_merged_global['precio_base'].min()
max = df_merged_global['precio_base'].max()
mediana = df_merged_global['precio_base'].median()

print(f"Precio promedio: {promedio}")
print(f"Precio mínimo: {min}")
print(f"Precio máximo: {max}")
print(f"mediana: {mediana}")

# 14.2 Calcular el precio promedio por categoría
df_merged_global['precio_base'] = pd.to_numeric(df_merged_global['precio_base'], errors='coerce')
precio_promedio = df_merged_global.groupby('categoria')['precio_base'].mean()
print(precio_promedio)

# 14.3 Encontrar los productos más caros y más baratos
productos_caros = df_merged_global.groupby('id_producto')['precio_base'].max().sort_values(ascending=False)
productos_baratos = df_merged_global.groupby('id_producto')['precio_base'].min().sort_values(ascending=True)
print(productos_caros)
print(productos_baratos)

# 14.4 Mostrar los top 10 productos más caros
productos_caros = df_merged_global.groupby('id_producto')['precio_base'].max().sort_values(ascending=False).head(10)
print(productos_caros)
# Out:
# Precio promedio: -772.5557475571841
# Precio mínimo: -99999.0
# Precio máximo: 1995.78
# mediana: 987.96
# categoria
# ###ERROR###   -9343.344174
# De             1169.806325
# Deporte         310.355649
# El             1992.650000
# Electrónica    -265.457438
# Ho             1200.847445
# Hogar          -259.499781
# Ju             1443.467876
# Juguetes       -780.589374
# Li             1487.425398
# Libros        -2374.565957
# Ro              602.196591
# Ropa           -634.634166
# Name: precio_base, dtype: float64
# id_producto
# 358.0    1995.78
# 341.0    1993.60
# 311.0    1992.65
# 660.0    1988.41
# 339.0    1987.29
#           ...
# 964.0        NaN
# 967.0        NaN
# 973.0        NaN
# 977.0        NaN
# nan          NaN
# Name: precio_base, Length: 1001, dtype: float64
# id_producto
# 448.0   -99999.0
# 409.0   -99999.0
# 516.0   -99999.0
# 603.0   -99999.0
# 164.0   -99999.0
#           ...
# 964.0        NaN
# 967.0        NaN
# 973.0        NaN
# 977.0        NaN
# nan          NaN
# Name: precio_base, Length: 1001, dtype: float64
# id_producto
# 358.0    1995.78
# 341.0    1993.60
# 311.0    1992.65
# 660.0    1988.41
# 339.0    1987.29
# 970.0    1986.45
# 528.0    1982.89
# 444.0    1982.67
# 367.0    1982.27
# 285.0    1982.10
# Name: precio_base, dtype: float64

# %% [markdown]
# ## Apartado 15: Productos más vendidos

# %%
# 15.1 Obtener el producto más vendido (cantidad vendida, total vendido, nombre del producto y categoría)
df_merged_global['precio_base'] = pd.to_numeric(df_merged_global['precio_base'], errors='coerce')
df_merged_global['total_vendido'] = df_merged_global['cantidad'] * df_merged_global['precio_base']

producto_mas_vendido = (
    df_merged_global.groupby(['id_producto', 'nombre', 'categoria'])
    .agg(
        cantidad_vendida=('cantidad', 'sum'),
        total_vendido=('total_vendido', 'sum')
    )
    .sort_values('cantidad_vendida', ascending=False)
)

print(producto_mas_vendido.head(1))
# Out:
# Empty DataFrame
# Columns: [cantidad_vendida, total_vendido]
# Index: []

# %% [markdown]
# ## Apartado 16: Análisis temporal

# %%
# 16.1 Obtener información sobre las ventas por mes (número total de ventas, número de pedidos y cantidad total)
df_csv['id_cliente'] = df_csv['id_cliente'].apply(lambda x: str(int(float(x))) if float(x).is_integer() else str(x))
df_json_cliente = df_json.merge(df_csv, on='id_cliente', how='inner')

df_json_cliente["fecha_registro"] = pd.to_datetime(df_json_cliente["fecha_registro"])
df_json_cliente['mes'] = df_json_cliente["fecha_registro"].dt.month
informacion_ventas_mes = df_json_cliente.groupby('mes').agg(
    num_ventas = ('total','sum'),
    numpedidos = ('id_cliente','count'),
    cantidad_total = ('cantidad','sum')
)
print(informacion_ventas_mes)

# 16.2 Obten la misma información pero en lugar de por mes, por semana.
df_json_cliente["fecha_registro"] = pd.to_datetime(df_json_cliente["fecha_registro"])
df_json_cliente['semana'] = df_json_cliente["fecha_registro"].dt.weekday
informacion_ventas_semana = df_json_cliente.groupby('semana').agg(
    num_ventas = ('total','sum'),
    numpedidos = ('id_cliente','count'),
    cantidad_total = ('cantidad','sum')
)
print(informacion_ventas_semana)
# Out:
#       num_ventas  numpedidos  cantidad_total
# mes
# 1    17989801.80        3326         17855.0
# 2    14991633.21        2824         15079.0
# 3    16928619.19        3221         17053.0
# 4    17877886.21        3372         18024.0
# 5    17937156.43        3409         18141.0
# 6    16570786.56        3226         16986.0
# 7    16531508.06        3189         16897.0
# 8    16383756.20        3108         16437.0
# 9    16042738.78        3081         16555.0
# 10   16738255.03        3316         17478.0
# 11   16152576.96        3103         16602.0
# 12   18581149.06        3484         18504.0
#          num_ventas  numpedidos  cantidad_total
# semana
# 0       28443707.01        5422         28641.0
# 1       29820423.80        5720         30323.0
# 2       28812520.83        5540         29351.0
# 3       29258539.96        5536         29553.0
# 4       29544470.59        5687         30312.0
# 5       28799119.58        5478         29207.0
# 6       28047085.72        5276         28224.0

# %% [markdown]
# ## Apartado 17: Duplicados

# %%
## 17.1 Contar filas duplicadas en cada uno de los datasets originales.
df_bd_copia = df_bd.copy()
df_bd_copia = df_bd_copia.applymap(lambda x: str(x) if isinstance(x, dict) else x)
df_csv_copia = df_csv.copy()
df_csv_copia = df_csv_copia.applymap(lambda y: str(y) if isinstance(y, dict) else y)
df_json_copia = df_json.copy()
df_json_copia = df_json_copia.applymap(lambda z: str(z) if isinstance(z, dict) else z)
df_bd_copia.duplicated().sum()
df_csv_copia.duplicated().sum()
df_json_copia.duplicated().sum()
# Out:
# C:\Users\ruben\AppData\Local\Temp\ipykernel_18632\3933850032.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_bd_copia = df_bd_copia.applymap(lambda x: str(x) if isinstance(x, dict) else x)
# C:\Users\ruben\AppData\Local\Temp\ipykernel_18632\3933850032.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_csv_copia = df_csv_copia.applymap(lambda y: str(y) if isinstance(y, dict) else y)
# C:\Users\ruben\AppData\Local\Temp\ipykernel_18632\3933850032.py:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_json_copia = df_json_copia.applymap(lambda z: str(z) if isinstance(z, dict) else z)
# np.int64(0)

# %% [markdown]
# ## Apartado 18: Valores faltantes

# %%
# 18.1 Obtener el porcentaje de valores faltantes en cada columna del dataset.
porcentaje_faltantes = df_merged_global.isna().mean() * 100
print(porcentaje_faltantes.round(2))
# Out:
# Id Pedido               0.00
# id_cliente              0.00
# id_producto             0.00
# fecha_pedido            4.85
# cantidad                3.25
# precio_unitario         3.41
# total                   3.28
# metodo_pago             3.22
# estado_pedido           3.27
# País envío              3.32
# nombre                100.00
# email                 100.00
# telefono              100.00
# direccion             100.00
# fecha_registro        100.00
# genero                100.00
# edad                  100.00
# nivel_fidelizacion    100.00
# nombre_producto         9.89
# categoria              10.01
# precio_base             9.94
# descuento               9.45
# stock                  10.14
# proveedor              10.05
# fecha_alta             10.10
# total_vendido          12.87
# dtype: float64

# %% [markdown]
# ## Apartado 19: Valoración final

# %% [markdown]
# Tras completar este ejercicio, ¿qué conclusiones has obtenido acerca de los datos? ¿Consideras que sería necesario aplicar algún tipo de preprocesamiento o crees que los datos son adecuados tal como están? Apoya tu valoración con ejemplos concretos de columnas que ilustren tu análisis.

# %% [markdown]
# <!-- Responde aquí al apartado 19 -->
# **Responder**
# Después de aplicar el merge se obseva que cuando se hace un left entre los dataframes se genera uno nuevo con mútiples nulos debido a que las claves no coinciden, (en el caso de csv por ejemplo, vemos que la clave es tipo float, mientras que en json es int), por otro lado si aplicamos un inner el resultado de la unión de los dataframes sería uno nuevo vacío.
# En consecuencia de lo mencionado, sería conveniente realizar preprocesamientos previos de los datos.
